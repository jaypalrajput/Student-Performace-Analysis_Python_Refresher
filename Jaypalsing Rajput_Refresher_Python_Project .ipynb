# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;
import re
import seaborn as sns

# %% [markdown]
# #Write a function del_char(s,c) that takes string s and c as input where c has length 1(i.e. a single character),and reaturn a string obtained by deleting all occurances of c.if c has length other than 1 ,then function should return s.

# %%
def del_char(s,c):
  
  s1 = s
 
  if(len(c)<=1):
    newstring = re.sub(c, '', s1 )
    print(newstring)
  else:
    print(s1)
del_char(input("enter String "),input("enter character to remove  "))

# %% [markdown]
# #Write a fumction shuffle(l1,l2) that takes two lists l1 and l2 as input and return a list consisting a first element in l1 and then first element in l2, next second element in l1 then second element in l2 and so on.If the two lists are not equal length then remaining elements are appended to end of the new list.

# %%
def shuffle(l1, l2):
    l3=[]
    if(len(l1)==len(l2)):
      l3= [sub[item] for item in range(len(l2))
                      for sub in [l1, l2]]
      print(l3)
    else:
      l3 = [ele for comb in zip(l1,l2) for ele in comb]
      set1 = set(l1)
      set2 = set(l2)
      missing=list(set(l2).difference(l1))
      #missing = list(sorted(set1 - set2))
      l3.extend(missing)
      print(l3)


l1 = [1, 2, 3]
l2 = [4, 5, 6,7,8]
print(shuffle(l1,l2))
# Out:
# [4, 5, 6, 7, 8]
# None

# %%
def shuffle(l1,l2):
  lst=[]
  i=j=0
  while i<= len(l1) and j<=len(l2):
    lst.append(l1[i])
    lst.append(l2[j])
    if i==len(l1)-1 and j<len(l2):
      lst=lst+l2[j+1:]
      break
    elif j==len(l2)-1 and i<len(l1):
      lst=lst+l1[i+1:]
      break
    i=i+1
    j=j+1
  return lst

l1=[1,2,3,4,5]
l2=[1,2,3,4,5,6]
l3=[]
l3=shuffle(l1,l2)
print(l3)

# %% [markdown]
# #Write a function expanding(L),that takes list of integer as L and return true if the adjacent difference between each pair of elements strickly increased.

# %%
def expanding(L):
  r1=[] 
  i=0
  for j in range(i+1,len(L)): 
    r=abs(L[i]-L[j]) 
    temp=L[i]  
    L[i]=L[j]
    L[j]=temp
    r1.append(r) 
  flag = 0 
  i1 = 1

  for i1 in range(0,len(r1)):  
    for j1 in range(i1+1,len(r1)):

      if(r1[i1] < r1[-1]):
          flag = 1  
  if (flag==1) :
    return True    
  else :
    return False
L=[1,3,7,2,9]
expanding(L)
# Out:
# True

# %% [markdown]
# **Introduction:**
#
# **Students Performance Dataset** , This dataset was related to student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires. Two datasets are provided regarding the performance in two distinct subjects: Mathematics (mat) and Portuguese language (por).
# **Dataset Features:**
# 1.	school :  student's school (binary: "GP" :  Gabriel Pereira or "MS" :  Mousinho da Silveira)
# 2.	sex :  student's sex (binary: "F" :  female or "M" :  male)
# 3.	age :  student's age (numeric: from 15 to 22)
# 4.	address :  student's home address type (binary: "U" :  urban or "R" :  rural)
# 5.	famsize :  family size (binary: "LE3" :  less or equal to 3 or "GT3" :  greater than 3)
# 6.	Pstatus :  parent's cohabitation status (binary: "T" :  living together or "A" :  apart)
# 7.	Medu :  mother's education (numeric: 0 :  none,  1 :  primary education (4th grade), 2 : 5th to 9th grade, 3 : secondary education or 4: higher education)
# 8.	Fedu :  father's education (numeric: 0 :  none,  1 :  primary education (4th grade), 2 : 5th to 9th grade, 3 : secondary education or 4 : higher education)
# 9.	Mjob :  mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
# 10.	Fjob :  father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
# 11.	reason :  reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
# 12.	guardian :  student's guardian (nominal: "mother", "father" or "other")
# 13.	traveltime :  home to school travel time (numeric: 1 :  <15 min., 2 :  15 to 30 min., 3 :  30 min. to 1 hour, or 4 :  >1 hour)
# 14.	studytime :  weekly study time (numeric: 1 :  <2 hours, 2 :  2 to 5 hours, 3 :  5 to 10 hours, or 4 :  >10 hours)
# 15.	failures :  number of past class failures (numeric: n if 1<=n<3, else 4)
# 16.	schoolsup :  extra educational support (binary: yes or no)
# 17.	famsup :  family educational support (binary: yes or no)
# 18.	paid :  extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19.	activities :  extra: curricular activities (binary: yes or no)
# 20.	nursery :  attended nursery school (binary: yes or no)
# 21.	higher :  wants to take higher education (binary: yes or no)
# 22.	internet :  Internet access at home (binary: yes or no)
# 23.	romantic :  with a romantic relationship (binary: yes or no)
# 24.	famrel :  quality of family relationships (numeric: from 1 :  very bad to 5 :  excellent)
# 25.	freetime :  free time after school (numeric: from 1 :  very low to 5 :  very high)
# 26.	goout :  going out with friends (numeric: from 1 :  very low to 5 :  very high)
# 27.	Dalc :  workday alcohol consumption (numeric: from 1 :  very low to 5 :  very high)
# 28.	Walc :  weekend alcohol consumption (numeric: from 1 :  very low to 5 :  very high)
# 29.	health :  current health status (numeric: from 1 :  very bad to 5 :  very good)
# 30.	absences :  number of school absences (numeric: from 0 to 93)
#
# Grade attributes:
# 31.	G1 :  first period grade (numeric: from 0 to 20)
# 32.	G2 :  second period grade (numeric: from 0 to 20)
# 33.	G3 :  final grade (numeric: from 0 to 20, output target)

# %%
#import dataset
studdf=pd.read_csv('/student-mat.csv',sep=';')

# %%
studdf.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
studdf['Subject']='Math' #Add Subject column

# %%
# To get shape of recieved dataset
studdf.shape
# Out:
# (395, 34)

# %% [markdown]
# The dataset has 395 observations and 33 Features which are match to descibed with received source of dataset.

# %%
df_stud_por=pd.read_csv('/student-por.csv',sep=';')
df_stud_por.head()
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        4   0  11  11
# 1     GP   F   17       U     GT3       T  ...     1       3        2   9  11  11
# 2     GP   F   15       U     LE3       T  ...     3       3        6  12  13  12
# 3     GP   F   15       U     GT3       T  ...     1       5        0  14  14  14
# 4     GP   F   16       U     GT3       T  ...     2       5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df_stud_por['Subject']='Por' #Add Subject column

# %%
df_stud_por.shape
# Out:
# (649, 34)

# %%
df_stud=pd.concat([studdf,df_stud_por], axis=0) #combining two data files with subject as discriminant column to distinguish columns

# %%
df_stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
# ...

# %%
#to check occurances of columnwise values
df_stud.value_counts()
# Out:
# school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob      Fjob      reason      guardian  traveltime  studytime  failures  schoolsup  famsup  paid  activities  nursery  higher  internet  romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3  Subject
# GP      F    15   R        GT3      T        1     1     at_home   other     home        mother    2           4          0         yes        yes     yes   yes         yes      yes     yes       no        3       1         2      1     1     1       4         13  13  13  Por        1
#         M    17   U        LE3      T        4     4     services  other     home        mother    1           2          0         no         yes     no    no          yes      yes     yes       yes       5       3         5      4     5     3       15        13  12  12  Por        1
# ...

# %%
# To Check  Columnwise unique values
df_stud.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      35
# G1            18
# G2            17
# G3            19
# Subject        2
# dtype: int64

# %%
# To Check sum of null values 
df_stud.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# Subject       0
# dtype: int64

# %%
# To Check five point summary of numerical columns
df_stud.describe()
# Out:
#                age         Medu  ...           G2           G3
# count  1044.000000  1044.000000  ...  1044.000000  1044.000000
# mean     16.726054     2.603448  ...    11.246169    11.341954
# std       1.239975     1.124907  ...     3.285071     3.864796
# min      15.000000     0.000000  ...     0.000000     0.000000
# 25%      16.000000     2.000000  ...     9.000000    10.000000
# 50%      17.000000     3.000000  ...    11.000000    11.000000
# 75%      18.000000     4.000000  ...    13.000000    14.000000
# max      22.000000     4.000000  ...    19.000000    20.000000
#
# [8 rows x 16 columns]

# %%
# To Check duplicated rows in dataset
df_stud.duplicated().sum()
# Out:
# 0

# %%
#To display Top 5 record
studdf.head()
# Out:
#   school sex  age address famsize Pstatus  ...  health  absences  G1  G2  G3 Subject
# 0     GP   F   18       U     GT3       A  ...       3         6   5   6   6    Math
# 1     GP   F   17       U     GT3       T  ...       3         4   5   5   6    Math
# 2     GP   F   15       U     LE3       T  ...       3        10   7   8  10    Math
# 3     GP   F   15       U     GT3       T  ...       5         2  15  14  15    Math
# 4     GP   F   16       U     GT3       T  ...       5         4   6  10  10    Math
#
# [5 rows x 34 columns]

# %%
#To display last 5 record
studdf.tail()
# Out:
#     school sex  age address famsize  ... absences  G1  G2  G3 Subject
# 390     MS   M   20       U     LE3  ...       11   9   9   9    Math
# 391     MS   M   17       U     LE3  ...        3  14  16  16    Math
# 392     MS   M   21       R     GT3  ...        3  10   8   7    Math
# 393     MS   M   18       R     LE3  ...        0  11  12  10    Math
# 394     MS   M   19       U     LE3  ...        5   8   9   9    Math
#
# [5 rows x 34 columns]

# %%
df_stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
# ...

# %% [markdown]
# info () function is used to get a concise summary of the dataframe.It includes summary of coulumn index ,column name, datatype, Not Null Details, Total datattype counts and Memory usage.The above info() details shows no any null values available in dataset.

# %%
f, ax = plt.subplots()
figure = sns.countplot(x = 'school', data=df_stud, order=['GP','MS'])
ax = ax.set(ylabel="Count", xlabel="school")
figure.grid(False)
plt.title('School Distribution')
plt.savefig('School.png', bbox_inches='tight')

# %% [markdown]
# The  "GP" :  Gabriel Pereira  has more strength of students as compare to "MS" :  Mousinho da Silveira

# %% [markdown]
# #Insights  students performance

# %%
dfsper=df_stud;
dfsper['PerformanceG1']=''
dfsper.head()
# Out:
#   school sex  age address famsize  ...  G1  G2  G3 Subject PerformanceG1
# 0     GP   F   18       U     GT3  ...   5   6   6    Math
# 1     GP   F   17       U     GT3  ...   5   5   6    Math
# 2     GP   F   15       U     LE3  ...   7   8  10    Math
# 3     GP   F   15       U     GT3  ...  15  14  15    Math
# 4     GP   F   16       U     GT3  ...   6  10  10    Math
#
# [5 rows x 35 columns]

# %%
# Feature Labeling with grading as Poor Good and Best
dfsper.loc[(dfsper.G3>=0)& (dfsper.G3<=7),'PerformanceG1'] = 'Poor'
dfsper.loc[(dfsper.G3>=8)& (dfsper.G3<=14),'PerformanceG1'] = 'Good'
dfsper.loc[(dfsper.G3>=15)& (dfsper.G3<=20),'PerformanceG1'] = 'Best'

# %%
# Grouping performance by subject
dfsper.groupby(['Subject'])['PerformanceG1'].value_counts()
# Out:
# Subject  PerformanceG1
# Math     Good             252
#          Best              73
#          Poor              70
# Por      Good             488
#          Best             131
#          Poor              30
# Name: PerformanceG1, dtype: int64

# %%
sns.countplot(x = 'PerformanceG1', data=dfsper)
plt.title("Overall Performance as per subject")
# Out:
# Text(0.5, 1.0, 'Overall Performance as per subject')

# %% [markdown]
# The overall performancewise student count maximum come under Good Category

# %%
dfsper['G3'] = dfsper['G1'] + dfsper['G2'] 

sns.distplot(dfsper['G3'], color = 'magenta')

plt.title('comparison of total score of all the students', fontweight = 30, fontsize = 20)
plt.xlabel('total score scored by the students')
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# with help of above visual we can see that comparisonwise  total score of all the students symetrically distributed in grades.

# %%
# Student performance status
perc = (lambda col: col/col.sum())
index = ['Poor','Good','Best']
per_tab1 = pd.crosstab(index=dfsper.PerformanceG1, columns=dfsper.Subject)
per_tab = np.log(per_tab1)
per_perc = per_tab.apply(perc).reindex(index)

# %%
plt.figure()
per_perc.plot.bar(colormap="BrBG", fontsize=12, figsize=(5,5))
plt.title('Students Performance ', fontsize=18)
plt.ylabel('Percentage of Student Counts ', fontsize=12)
plt.xlabel('Performance in Subject', fontsize=12)
plt.show()

# %% [markdown]
# The above visual shows most of students performance in Math subject falls in Poor as compare to Por. subject. It is also increasing about por.in Good and Best group of performance. Overall amximum count of studentd come under Good Performance category.

# %%
sns.set(rc = {'figure.figsize':(10,8)})
sns.heatmap(dfsper.corr())

# %% [markdown]
# The Mother Education ,Father Education,Drinking Alcohol, Weekly Dirinking Alcohol,G1,G2 variables Highly corelated with Final Grade Performance.

# %%
df_new=dfsper[['schoolsup', 'famsup', 'nursery','health','Subject','G3']]
df_new[:3]
# Out:
#   schoolsup famsup nursery  health Subject  G3
# 0       yes     no     yes       3    Math   6
# 1        no    yes      no       3    Math   6
# 2       yes     no     yes       3    Math  10

# %% [markdown]
# #relations exist schoolsup, famsup, nursery,health etc with the grades of the subject

# %%
df1=df_new[df_new.Subject=='Math']

for i in df_new:  
  if i!='G3':
    sns.catplot(x=i,y='G3',kind='box',data=df1)
df1=df_new[df_new.Subject=='Por']
for i in df_new:  
  if i!='G3':
    sns.catplot(x=i,y='G3',kind='box',data=df1)

# %% [markdown]
# The above visual shows impact of social variables['schoolsup', 'famsup', 'nursery','health'] on student performance .

# %% [markdown]
# #Insights about the effect of home environment on students performance

# %%
dfsper.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'Subject',
#        'PerformanceG1'],
#       dtype='object')

# %%
df_env=dfsper[['Medu', 'Fedu', 'romantic','goout','Dalc','Walc','Subject','G3']]
df_env[:3]
# Out:
#    Medu  Fedu romantic  goout  Dalc  Walc Subject  G3
# 0     4     4       no      4     1     1    Math   6
# 1     1     1       no      3     1     1    Math   6
# 2     1     1       no      2     2     3    Math  10

# %%
plt.figure(figsize=(6,10))
plt.title('Final Grade By Frequency of Envirinmental Features', fontsize=20)
plt.ylabel('Final Score', fontsize=16)
plt.xlabel('Frequency of Envirinmental Features', fontsize=16)
for i in df_env:  
  if i!='G3':
    sns.boxplot(x=i, y='G3', data=df_env )

# %% [markdown]
# The above visual shows impact of environmental variables['Medu', 'Fedu', 'romantic','goout','Dalc','Walc' on student performance of both Math and Por. subjects.The major negative impact of variables may seen on Math Subject where maximum students fall below the poor scores.

# %% [markdown]
# # Final grade attribute G3 dependancy on G1 and G2 grades

# %%
m, b = np.polyfit(dfsper['G1'],dfsper['G2'], 1)
plt.plot(dfsper['G1'], m*dfsper['G1'] + b)
plt.scatter(dfsper['G1'],dfsper['G2'],s=dfsper['G3'],c='red')

# %% [markdown]
# -	Final grade attribute G3 will definitely be highly dependent on G1 and G2 grades.

# %% [markdown]
# **Conclusion**
# The above analysis of dataset includes different social, eduacatinal and environmental features which affects to the performance of the students in two schools. In analysis first i merge two dataset and perform descriptive analysis.In descriptive analysis. After descriptive analysis i try to see visual related to subjectwise performance of students and comaparative performance.Next i see coreations hips among variables and impact of social and environmental featutres on student performance.
